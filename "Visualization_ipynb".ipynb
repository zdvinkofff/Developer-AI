# %% [markdown]
# <a href="https://colab.research.google.com/github/zdvinkofff/Developer-AI/blob/main/%22Visualization_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Выполните несколько упражнений по визуализации данных из датасета

# %% [markdown]
# ## Упражнение 1
# Загрузите [датасет](https://drive.google.com/file/d/19Xb7iK7Hb2m1a9XPSJNNKKNn-7h-phg6/view?usp=sharing). Пропустите первые две строки (аргумент skiprows). Выведите датасет на экран.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Marketing_Analysis.csv', skiprows=2)
df
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %% [markdown]
# ## Упражнение 2
# Для загруженного датасета визуализируйте графики пар количественных признаков с помощью библиотеки seaborn. Пример построения графиков пар признаков был показан в [уроке](https://academy.mob-edu.ru/ui/index.html#/bookshelf/course/354/topic/4224/lesson/10515).
#
# Если будут возникать ошибки из-за пропуска данных, очистите датасет от пропусков.

# %%
# !pip install seaborn

# %%
import seaborn as sns
import numpy as np

# %%
df['targeted'].replace('yes', 0, inplace=True)
df['targeted'].replace('no', 1, inplace=True)
df['default'].replace('yes', 0, inplace=True)
df['default'].replace('no', 1, inplace=True)
df['housing'].replace('yes', 0, inplace=True)
df['housing'].replace('no', 1, inplace=True)
df['loan'].replace('yes', 0, inplace=True)
df['loan'].replace('no', 1, inplace=True)
df['response'].replace('yes', 0, inplace=True)
df['response'].replace('no', 1, inplace=True)
df
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
# ...

# %%
# pd.isnull(df)
# df.fillna(0)
df.drop(columns = ['duration', 'marital', 'jobedu', 'contact', 'poutcome'],axis = 1)
# Out:
#        customerid   age  salary  balance  targeted  default  housing  loan  \
# 0               1  58.0  100000     2143         0        1        0     1
# 1               2  44.0   60000       29         0        1        0     1
# 2               3  33.0  120000        2         0        1        0     0
# 3               4  47.0   20000     1506         1        1        0     1
# 4               5  33.0       0        1         1        1        1     1
# ...           ...   ...     ...      ...       ...      ...      ...   ...
# 45206       45207  51.0   60000      825         0        1        1     1
# 45207       45208  71.0   55000     1729         0        1        1     1
# 45208       45209  72.0   55000     5715         0        1        1     1
# 45209       45210  57.0   20000      668         0        1        1     1
# 45210       45211  37.0  120000     2971         0        1        1     1
#
#        day      month  campaign  pdays  previous  response
# ...

# %%
df

# %%
sns.pairplot(df, hue=None)

# %% [markdown]
# ## Упражнение 3
# Постройте [корреляционную матрицу](https://pythobyte.com/correlation-matrix-in-python-34345/) для количественных данных датасета.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sn

# %%
numeric_col = ['customerid',	'age',	'salary',	'balance']

# %%
corr_matrix = df.loc[:,numeric_col].corr()
print(corr_matrix)
# Out:
#             customerid       age    salary   balance
# customerid    1.000000  0.014906  0.039966  0.073639
# age           0.014906  1.000000  0.024374  0.097755
# salary        0.039966  0.024374  1.000000  0.055469
# balance       0.073639  0.097755  0.055469  1.000000

# %%
sn.heatmap(corr_matrix, annot=True)
